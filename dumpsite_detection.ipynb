# %% [markdown]
# <a href="https://colab.research.google.com/github/booth95/TSS/blob/master/dumpsite_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# importing libraries

import numpy as np
import pandas as pd # for data processing
import os
import random

# %%
# importing libraries for data visualisation

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
# importing tensorflow for model creation and its dependancies

import tensorflow

#generate batches of tensor image data with real-time data augmentation

from keras.preprocessing.image import ImageDataGenerator

# %%
# for enabling inline plotting
# %matplotlib inline

training = '/content/drive/MyDrive/Project/Train'
testing = '/content/drive/MyDrive/Project/Test'
validation = '/content/drive/MyDrive/Project/Validate'

# %%
# defining pre-processing transformation on raw images of training data

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range = 0.1,
        zoom_range = 0.1,
        horizontal_flip = True
        )

# %%
# defining pre-processing transformations on raw images of testing data
test_datagen = ImageDataGenerator (rescale = 1./255)

# %%
# Generating training data

training_set = train_datagen.flow_from_directory(
        training,
        target_size = (220, 220),
        batch_size = 32,
        class_mode = 'categorical'
        )
# Out:
# Found 352 images belonging to 2 classes.

# %%
# Generating testing data

test_set = train_datagen.flow_from_directory(
        testing,
        target_size = (220, 220),
        batch_size = 32,
        class_mode = 'categorical'
        )
# Out:
# Found 75 images belonging to 2 classes.

# %%
valid_set = train_datagen.flow_from_directory(
        validation,
        target_size = (220, 220),
        batch_size = 32,
        class_mode = 'categorical'
        )
# Out:
# Found 50 images belonging to 2 classes.

# %%
# Reading the image data
# function to plot any random image from dataset

def showImages(class_name):
        random_index = random.choice(list(range(1, 50)))
        folder_path = os.path.join(training, class_name)
        try:
            image_path = os.path.join(folder_path, str(random_index).zfill(2)+'.png')
            plt.imshow(mpimg.imread(image_path))
        except:
            image_path = os.path.join(folder_path, str(random_index).zfill(2) + '.png')
            plt.imshow(mpimg.imread(image_path))
        plt.title(class_name)
        plt.axis(False)

plt.figure(figsize = (20, 20))
for labels,number in training_set.class_indices.items():
    plt.subplot(6,6,number+1)
    showImages(labels)

# %%
# printing class labels for each face
test_set.class_indices
# Out:
# {'Non-dumpsites': 0, 'dumpsites': 1}

# %%
#creating a list of sites

TrainClasses = training_set.class_indices
ResultMap={}
for siteValue,siteName in zip(TrainClasses.values(),TrainClasses.keys()):
    ResultMap[siteValue] = siteName

import pickle
with open(R'/content/drive/MyDrive/Project/ResultsMap.pkl', 'wb') as f:
    pickle.dump(ResultMap, f, pickle.HIGHEST_PROTOCOL)

    print('mapping of Face and its ID', ResultMap)
# Out:
# mapping of Face and its ID {0: 'Non-dumpsites', 1: 'dumpsites'}

# %%
# number of neurons of the output layer is the same as the number of faces

OutputNeurons = len(ResultMap)
print('\n The number of output neurons: ', OutputNeurons)
# Out:
#  The number of output neurons:  2

# %%
# creating the CNN model
#!pip install tensorflow

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

# %%
# initializing the CNN

classifier = Sequential()

# first layer of CNN
classifier.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1),
                      input_shape=(220, 220, 3), activation = 'relu'))

# add pooling layer

classifier.add(MaxPool2D(pool_size=(2, 2)))
classifier.add(Conv2D(64, kernel_size=(5, 5), strides=(1, 1), input_shape=(220, 220, 3), activation='relu'))

classifier.add(MaxPool2D(pool_size=(2, 2)))

# flattening

classifier.add(Flatten())

#fully connected network
OutputNeurons =2
classifier.add(Dense(256, activation = 'relu'))
classifier.add(Dense(OutputNeurons, activation = 'softmax'))

# compiling CNN

from tensorflow.keras.optimizers import Adam

opt_1 = Adam(learning_rate = 0.0001)

classifier.compile(loss = 'categorical_crossentropy', optimizer = opt_1, metrics = ["accuracy"])

classifier.summary
# Out:
# <bound method Model.summary of <keras.src.engine.sequential.Sequential object at 0x7e036c245f90>>

# %%
# importing a model
# measuring the time taken by the model

import time

StartTime = time.time()

# %%
# start model training

model_history = classifier.fit_generator(
        training_set,
        steps_per_epoch = len(training_set),
        epochs = 25,
        validation_data = valid_set,
        validation_steps = len(valid_set),
        verbose = 1
        )
EndTime = time.time()
print("######### Total Time Taken:", round((EndTime-StartTime)/60), "Minutes ##########")
# Out:
# <ipython-input-154-dbc1d77d2e8b>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = classifier.fit_generator(
# Epoch 1/25
# 11/11 [==============================] - 80s 7s/step - loss: 0.9694 - accuracy: 0.5057 - val_loss: 0.7846 - val_accuracy: 0.5000
# Epoch 2/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.6928 - accuracy: 0.5170 - val_loss: 0.6739 - val_accuracy: 0.5200
# Epoch 3/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.6452 - accuracy: 0.6506 - val_loss: 0.6100 - val_accuracy: 0.7800
# Epoch 4/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.6001 - accuracy: 0.8097 - val_loss: 0.5583 - val_accuracy: 0.9000
# Epoch 5/25
# 11/11 [==============================] - 69s 6s/step - loss: 0.5508 - accuracy: 0.7869 - val_loss: 0.5379 - val_accuracy: 0.7800
# Epoch 6/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.5200 - accuracy: 0.7472 - val_loss: 0.5829 - val_accuracy: 0.6000
# Epoch 7/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.4792 - accuracy: 0.7841 - val_loss: 0.5105 - val_accuracy: 0.7400
# Epoch 8/25
# 11/11 [==============================] - 69s 6s/step - loss: 0.3932 - accuracy: 0.8807 - val_loss: 0.3200 - val_accuracy: 0.9400
# Epoch 9/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.3220 - accuracy: 0.9091 - val_loss: 0.2507 - val_accuracy: 0.9400
# Epoch 10/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.2735 - accuracy: 0.9148 - val_loss: 0.2344 - val_accuracy: 0.9400
# Epoch 11/25
# 11/11 [==============================] - 70s 6s/step - loss: 0.2422 - accuracy: 0.9176 - val_loss: 0.1748 - val_accuracy: 0.9600
# Epoch 12/25
# 11/11 [==============================] - 68s 6s/step - loss: 0.1967 - accuracy: 0.9347 - val_loss: 0.1532 - val_accuracy: 0.9800
# Epoch 13/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.1872 - accuracy: 0.9460 - val_loss: 0.1643 - val_accuracy: 0.9600
# Epoch 14/25
# 11/11 [==============================] - 70s 6s/step - loss: 0.2214 - accuracy: 0.9062 - val_loss: 0.1136 - val_accuracy: 0.9800
# Epoch 15/25
# 11/11 [==============================] - 68s 6s/step - loss: 0.2079 - accuracy: 0.9176 - val_loss: 0.1208 - val_accuracy: 0.9600
# Epoch 16/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.1319 - accuracy: 0.9773 - val_loss: 0.1067 - val_accuracy: 0.9800
# Epoch 17/25
# 11/11 [==============================] - 68s 6s/step - loss: 0.1265 - accuracy: 0.9716 - val_loss: 0.2323 - val_accuracy: 0.9000
# Epoch 18/25
# 11/11 [==============================] - 70s 6s/step - loss: 0.1248 - accuracy: 0.9716 - val_loss: 0.1038 - val_accuracy: 0.9600
# Epoch 19/25
# 11/11 [==============================] - 68s 6s/step - loss: 0.0940 - accuracy: 0.9801 - val_loss: 0.2841 - val_accuracy: 0.8800
# Epoch 20/25
# 11/11 [==============================] - 68s 6s/step - loss: 0.1260 - accuracy: 0.9517 - val_loss: 0.0805 - val_accuracy: 0.9800
# Epoch 21/25
# 11/11 [==============================] - 70s 6s/step - loss: 0.1498 - accuracy: 0.9545 - val_loss: 0.1410 - val_accuracy: 0.9600
# Epoch 22/25
# 11/11 [==============================] - 69s 6s/step - loss: 0.1467 - accuracy: 0.9347 - val_loss: 0.3065 - val_accuracy: 0.8800
# Epoch 23/25
# 11/11 [==============================] - 67s 6s/step - loss: 0.1242 - accuracy: 0.9574 - val_loss: 0.1397 - val_accuracy: 0.9400
# Epoch 24/25
# 11/11 [==============================] - 68s 6s/step - loss: 0.0719 - accuracy: 0.9886 - val_loss: 0.1082 - val_accuracy: 0.9600
# Epoch 25/25
# 11/11 [==============================] - 68s 6s/step - loss: 0.0658 - accuracy: 0.9886 - val_loss: 0.0945 - val_accuracy: 0.9800
# ######### Total Time Taken: 30 Minutes ##########

# %%
# model history

accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# %%
#plotting

plt.figure(figsize=(15,10))
plt.subplot(2, 2, 1)
plt.plot(accuracy, label = "Training accuracy")
plt.plot(val_accuracy, label = 'Validation accuracy')
plt.legend()
plt.title('Training vs Validation accuracy')

plt.subplot(2,2,2)
plt.plot(loss, label = 'Training loss')
plt.plot(val_loss, label = 'Validation loss')
plt.legend()
plt.title('Training vs validation loss')

plt.show()

# %%
# saving the model
classifier.save('/content/Drive/MyDrive/project/train/classifier.pkl')

# %%
#testing the model

from tensorflow.keras.utils import load_img, img_to_array

# %%
# test positive result
testImage = "//content/drive/MyDrive/Project/Test/dumpsites/1.png"
test_image = load_img(testImage, target_size = (220, 220))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image, verbose = 0)

img = cv2.imread(testImage)

plt.imshow(img)
plt.title('picture')
plt.show()
print('######' * 10)
print('Prediction is: ',ResultMap[np.argmax(result)])
# Out:
# ############################################################
# Prediction is:  dumpsites

# %%
# test negative result
testImage = "/content/drive/MyDrive/Project/Test/Non-dumpsites/Copy of Screenshot 2024-03-27hg 011113.png"
test_image = load_img(testImage, target_size = (220, 220))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image, verbose = 0)

img = cv2.imread(testImage)

plt.imshow(img)
plt.title('picture')
plt.show()

print('######' * 10)
print('Prediction is: ' ,ResultMap[np.argmax(result)])
# Out:
# ############################################################
# Prediction is:  Non-dumpsites
